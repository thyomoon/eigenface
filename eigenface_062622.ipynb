# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
### construct dataset

# set data directory 
os.chdir('/Users/taylormoon/Library/CloudStorage/OneDrive-UniversityofIllinois-Urbana/SIAI/coding/COM502/lecture5/EigenFace')
fullpath = 'db/1c.jpg'

df = pd.read_csv('index.csv',  encoding='utf-8-sig', sep=';')
df.columns = [i.replace(" ", '') for i in df]
print(df.columns)
print(df.dtypes)

# check the format of data
print(pd.unique(df.Gender))
# change Gender into male = 1, female = 2 
df['Gender'] = [1 if i == ' H ' else 2 for i in df.Gender]


# check the format of data
print(pd.unique(df.Party))
# eliminate spaces
df['Party'] = df['Party'].replace(" ", '', regex=True)


# set Num to index and sort by
df = df.set_index('Num')
df = df.sort_values(by=['Num'])

print(df.dtypes)
df
# Out:
# Index(['Num', 'Name', 'Surname', 'Gender', 'Party'], dtype='object')
# Num         int64
# Name       object
# Surname    object
# Gender     object
# Party      object
# dtype: object
# [' H ' ' M ']
# [' GS  ' ' GC-CiU  ' ' GP  ' ' GIV-IU-ICV  ' ' GER-ERC  ' ' GV   '
#  ' GMx  ' ' GCC  ']
# Name       object
# Surname    object
# Gender      int64
# Party      object
# dtype: object
#                       Name                           Surname  Gender Party
# Num
# 1                Gonzalo                      Robles Orozco        1    GP
# 2       Francisco Miguel                  Fernández Marugán        1    GS
# 3                Arsenio     Fernández de Mesa Díaz del Río        1    GP
# 4                  Jesús                     Merino Delgado        1    GP
# 5      Francisco Antonio                     González Pérez        1    GP
# ..                     ...                               ...     ...   ...
# ...

# %%
### separate male and female data

df_male = df.loc[df.Gender == 1]
df_female = df.loc[df.Gender == 2]

# %%
### cleaning data directory
from PIL import Image

# remove unnecessary folder
dataset_dir = os.listdir('db')
dataset_dir.remove('orig')

## setting image size
# get width and height 
img = Image.open(fullpath)

wid = img.width
hei = img.height
print(wid, hei)
# Out:
# 85 86
